# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gymbook import gymbook as gb
from gymbook import utilities as utils
from gymbook import charting as chrt
import os
import config

# %%
df = gb.read_logs(f"{config.PROJECT_PATH}data\\GymBook-Logs-2020-27-03.csv")
df.head()
# Out:
#         Date     Workout   Time               Exercise Region  \
# 0 2020-03-26  Essentials  11:39  Barbell Bench Presses  Chest
# 1 2020-03-26  Essentials  11:41  Barbell Bench Presses  Chest
# 2 2020-03-26  Essentials  11:42  Barbell Bench Presses  Chest
# 3 2020-03-26  Essentials  11:46         Barbell Squats   Legs
# 4 2020-03-26  Essentials  11:47         Barbell Squats   Legs
#
#   Muscle Group (Primary) Muscle Group (Secondary)  Repetitions / Time  \
# 0              Pectorals            Arm extensors                   6
# 1              Pectorals            Arm extensors                   6
# 2              Pectorals            Arm extensors                   6
# 3             Quadriceps                   Glutes                   6
# 4             Quadriceps                   Glutes                   6
#
#    Weight / Distance Notes Skipped  dayofweekidx dayofweek  Timefloat  \
# 0               40.0            No             3  Thursday  11.650000
# ...

# %%
agg_exercises = gb.aggregate_exercises(df)
agg_exercises
# Out:
#         Date               Exercise  Repetitions / Time  Weight / Distance  \
# 0 2020-03-23   Barbell Back Presses                  18               60.0
# 1 2020-03-23  Barbell Bench Presses                  18              120.0
# 2 2020-03-23      Barbell Deadlifts                  18              120.0
# 3 2020-03-23         Barbell Squats                  18               60.0
# 4 2020-03-23  Dumbbell One-Arm Rows                  18               30.0
# 5 2020-03-26   Barbell Back Presses                  18               60.0
# 6 2020-03-26  Barbell Bench Presses                  18              120.0
# 7 2020-03-26      Barbell Deadlifts                  18               80.0
# 8 2020-03-26         Barbell Squats                  18               90.0
# 9 2020-03-26  Dumbbell One-Arm Rows                  18               30.0
#
#    Weight Lifted  Number Average Rep Weight
# 0          360.0                  20.000000
# 1          720.0                  40.000000
# ...

# %%
chrt.number_average_rep_weight_exercise(agg_exercises, "Barbell Deadlifts")
# Out:
# C:\Users\Liam\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
